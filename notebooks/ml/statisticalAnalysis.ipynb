# %%
import pandas as pd
store = pd.read_csv("../../data/ml/SampleSuperstore.csv")

# %%
print("Summary statistics of the dataset :")
print(store.describe())
# Out:
# Summary statistics of the dataset :
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55186.627539    229.856670     3.789753     0.156218    28.652464
# std    32063.103801    623.276273     2.225149     0.206456   234.271411
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728000
# 50%    56301.000000     54.480000     3.000000     0.200000     8.662000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#print dataset info
print("Info of the dataset :")
print(store.info())
# Out:
# Info of the dataset :
# <class 'pandas.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9993 non-null   str
#  1   Segment       9993 non-null   str
#  2   Country       9993 non-null   str
#  3   City          9993 non-null   str
#  4   State         9993 non-null   str
#  5   Postal Code   9993 non-null   int64
#  6   Region        9993 non-null   str
#  7   Category      9993 non-null   str
#  8   Sub-Category  9993 non-null   str
#  9   Sales         9993 non-null   float64
#  10  Quantity      9993 non-null   int64
#  11  Discount      9993 non-null   float64
#  12  Profit        9993 non-null   float64
# dtypes: float64(3), int64(2), str(8)
# memory usage: 1015.0 KB
# None

# %%
store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='str')

# %%
store_cat=store[['Ship Mode', 'Segment', 'Country', 'City', 'State','Region', 'Category', 'Sub-Category']]
store_num=store[['Postal Code', 'Sales', 'Quantity', 'Discount','Profit']]

# %%
print(store_cat.info())
print(store_num.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9993 non-null   str
#  1   Segment       9993 non-null   str
#  2   Country       9993 non-null   str
#  3   City          9993 non-null   str
#  4   State         9993 non-null   str
#  5   Region        9993 non-null   str
#  6   Category      9993 non-null   str
#  7   Sub-Category  9993 non-null   str
# dtypes: str(8)
# memory usage: 624.7 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Postal Code  9993 non-null   int64
#  1   Sales        9993 non-null   float64
#  2   Quantity     9993 non-null   int64
#  3   Discount     9993 non-null   float64
#  4   Profit       9993 non-null   float64
# dtypes: float64(3), int64(2)
# ...

# %%
#memory allocation done by python constructor

# %%
#For categorical data we get only count, unique, top, frequency
print(store_cat.describe())
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9993      9993           9993           9993        9993
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5190           9993            915        2000
#
#        Region         Category Sub-Category
# count    9993             9993         9993
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3202             6025         1523

# %%
#For numerical data we get only count, mean, std, min, 25%, 50%, 75% max
print(store_num.describe())
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55186.627539    229.856670     3.789753     0.156218    28.652464
# std    32063.103801    623.276273     2.225149     0.206456   234.271411
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728000
# 50%    56301.000000     54.480000     3.000000     0.200000     8.662000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#For categorical data we get only count, unique, top, frequency
print(store.describe(include='object'))
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9993      9993           9993           9993        9993
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5190           9993            915        2000
#
#        Region         Category Sub-Category
# count    9993             9993         9993
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3202             6025         1523
# C:\Users\subha\AppData\Local\Temp\ipykernel_19164\791172644.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# ...

# %%
#For numerical data we get only count, mean, std, min, 25%, 50%, 75% max
print(store.describe(include='number'))
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55186.627539    229.856670     3.789753     0.156218    28.652464
# std    32063.103801    623.276273     2.225149     0.206456   234.271411
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728000
# 50%    56301.000000     54.480000     3.000000     0.200000     8.662000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Transpose descriptive statistics
print (store.describe().T)
# Out:
#               count          mean           std       min        25%  \
# Postal Code  9993.0  55186.627539  32063.103801  1040.000  23223.000
# Sales        9993.0    229.856670    623.276273     0.444     17.280
# Quantity     9993.0      3.789753      2.225149     1.000      2.000
# Discount     9993.0      0.156218      0.206456     0.000      0.000
# Profit       9993.0     28.652464    234.271411 -6599.978      1.728
#
#                    50%        75%        max
# Postal Code  56301.000  90008.000  99301.000
# Sales           54.480    209.940  22638.480
# Quantity         3.000      5.000     14.000
# Discount         0.200      0.200      0.800
# Profit           8.662     29.364   8399.976

# %%
#datat type of columns
print(store.dtypes)
print(store.dtypes.value_counts())
# Out:
# Ship Mode           str
# Segment             str
# Country             str
# City                str
# State               str
# Postal Code       int64
# Region              str
# Category            str
# Sub-Category        str
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object
# str        8
# float64    3
# int64      2
# Name: count, dtype: int64
